# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:\\Users\sriveera\Documents\hospitals_data.csv")

# %%
df.head()
# Out:
#     region region_code  period  atleast_one_measure  immunization_measure  \
# 0  Alabama          AL    2013                 0.90                  0.73
# 1  Alabama          AL    2014                 0.90                  0.84
# 2  Alabama          AL    2015                  NaN                  0.96
# 3   Alaska          AK    2013                 1.00                  0.93
# 4   Alaska          AK    2014                 0.89                  0.92
#
#    reportable_lab_results_measure  syndromic_surveillance_measure  \
# 0                            0.10                            0.16
# 1                            0.41                            0.50
# 2                            0.93                            0.97
# 3                            0.07                            0.00
# 4                            0.31                            0.31
#
#    registry_measure  stage_2_hospitals_all_measures  \
# 0               NaN                            0.00
# ...

# %%
df.columns
# Out:
# Index(['region', 'region_code', 'period', 'atleast_one_measure',
#        'immunization_measure', 'reportable_lab_results_measure',
#        'syndromic_surveillance_measure', 'registry_measure',
#        'stage_2_hospitals_all_measures', 'stage_1_hospitals_all_measures'],
#       dtype='object')

# %%
 df.columns.str.upper()
# Out:
# Index(['REGION', 'REGION_CODE', 'PERIOD', 'ATLEAST_ONE_MEASURE',
#        'IMMUNIZATION_MEASURE', 'REPORTABLE_LAB_RESULTS_MEASURE',
#        'SYNDROMIC_SURVEILLANCE_MEASURE', 'REGISTRY_MEASURE',
#        'STAGE_2_HOSPITALS_ALL_MEASURES', 'STAGE_1_HOSPITALS_ALL_MEASURES'],
#       dtype='object')

# %%
df.rename(columns={'ATLEAST_ONE_MEASURE':'ONE MEASURE','IMMUNIZATION_MEASURE':'IMMUNIZATION','REPORTABLE_LAB_RESULTS_MEASURE':'LAB RESULTS','SYNDROMIC_SURVEILLANCE_MEASURE':'SYNDROMIC SURVEILLANCE','REGISTRY_MEASURE':'REGISTRY','STAGE_2_HOSPITALS_ALL_MEASURES':'STAGE 2 MEASURES','STAGE_1_HOSPITALS_ALL_MEASURES':'STAGE 1 MEASURES'},inplace=True)

# %%
df.head()
# Out:
#     REGION REGION_CODE  PERIOD  ONE MEASURE  IMMUNIZATION  LAB RESULTS  \
# 0  Alabama          AL    2013         0.90          0.73         0.10
# 1  Alabama          AL    2014         0.90          0.84         0.41
# 2  Alabama          AL    2015          NaN          0.96         0.93
# 3   Alaska          AK    2013         1.00          0.93         0.07
# 4   Alaska          AK    2014         0.89          0.92         0.31
#
#    SYNDROMIC SURVEILLANCE  REGISTRY  STAGE 2 MEASURES  STAGE 1 MEASURES
# 0                    0.16       NaN              0.00              0.00
# 1                    0.50       NaN              0.96              0.17
# 2                    0.97      0.04               NaN               NaN
# 3                    0.00       NaN              0.00              0.00
# 4                    0.31       NaN              1.00              0.00

# %%
df.isnull().sum()
# Out:
# REGION                      0
# REGION_CODE                 0
# PERIOD                      0
# ONE MEASURE                52
# IMMUNIZATION                0
# LAB RESULTS                 0
# SYNDROMIC SURVEILLANCE      0
# REGISTRY                  104
# STAGE 2 MEASURES           52
# STAGE 1 MEASURES           52
# dtype: int64

# %%
df.isnull().any()
# Out:
# REGION                    False
# REGION_CODE               False
# PERIOD                    False
# ONE MEASURE                True
# IMMUNIZATION              False
# LAB RESULTS               False
# SYNDROMIC SURVEILLANCE    False
# REGISTRY                   True
# STAGE 2 MEASURES           True
# STAGE 1 MEASURES           True
# dtype: bool

# %%
df.isnull().any().any()
# Out:
# True

# %%
df.isnull().sum()
# Out:
# REGION                      0
# REGION_CODE                 0
# PERIOD                      0
# ONE MEASURE                52
# IMMUNIZATION                0
# LAB RESULTS                 0
# SYNDROMIC SURVEILLANCE      0
# REGISTRY                  104
# STAGE 2 MEASURES           52
# STAGE 1 MEASURES           52
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 260

# %%
df
# Out:
#                    REGION REGION_CODE  PERIOD  ONE MEASURE  IMMUNIZATION  \
# 0                 Alabama          AL    2013         0.90          0.73
# 1                 Alabama          AL    2014         0.90          0.84
# 2                 Alabama          AL    2015          NaN          0.96
# 3                  Alaska          AK    2013         1.00          0.93
# 4                  Alaska          AK    2014         0.89          0.92
# 5                  Alaska          AK    2015          NaN          0.92
# 6                 Arizona          AZ    2013         0.93          0.80
# 7                 Arizona          AZ    2014         0.84          0.80
# 8                 Arizona          AZ    2015          NaN          0.98
# 9                Arkansas          AR    2013         0.76          0.65
# 10               Arkansas          AR    2014         0.94          0.78
# 11               Arkansas          AR    2015          NaN          1.00
# ...

# %%
df.describe()
# Out:
#             PERIOD  ONE MEASURE  IMMUNIZATION  LAB RESULTS  \
# count   156.000000   104.000000    156.000000   156.000000
# mean   2014.000000     0.841346      0.735256     0.491218
# std       0.819126     0.149874      0.242961     0.322775
# min    2013.000000     0.200000      0.050000     0.000000
# 25%    2013.000000     0.800000      0.597500     0.187500
# 50%    2014.000000     0.900000      0.790000     0.465000
# 75%    2015.000000     0.930000      0.950000     0.840000
# max    2015.000000     1.000000      1.000000     1.000000
#
#        SYNDROMIC SURVEILLANCE   REGISTRY  STAGE 2 MEASURES  STAGE 1 MEASURES
# count              156.000000  52.000000        104.000000         104.00000
# mean                 0.492564   0.035769          0.348558           0.02500
# std                  0.334475   0.046118          0.403036           0.05169
# min                  0.000000   0.000000          0.000000           0.00000
# ...

# %%
df.head()
# Out:
#     REGION REGION_CODE  PERIOD  ONE MEASURE  IMMUNIZATION  LAB RESULTS  \
# 0  Alabama          AL    2013         0.90          0.73         0.10
# 1  Alabama          AL    2014         0.90          0.84         0.41
# 2  Alabama          AL    2015          NaN          0.96         0.93
# 3   Alaska          AK    2013         1.00          0.93         0.07
# 4   Alaska          AK    2014         0.89          0.92         0.31
#
#    SYNDROMIC SURVEILLANCE  REGISTRY  STAGE 2 MEASURES  STAGE 1 MEASURES
# 0                    0.16       NaN              0.00              0.00
# 1                    0.50       NaN              0.96              0.17
# 2                    0.97      0.04               NaN               NaN
# 3                    0.00       NaN              0.00              0.00
# 4                    0.31       NaN              1.00              0.00

# %%
df.fillna(0)
# Out:
#                    REGION REGION_CODE  PERIOD  ONE MEASURE  IMMUNIZATION  \
# 0                 Alabama          AL    2013         0.90          0.73
# 1                 Alabama          AL    2014         0.90          0.84
# 2                 Alabama          AL    2015         0.00          0.96
# 3                  Alaska          AK    2013         1.00          0.93
# 4                  Alaska          AK    2014         0.89          0.92
# 5                  Alaska          AK    2015         0.00          0.92
# 6                 Arizona          AZ    2013         0.93          0.80
# 7                 Arizona          AZ    2014         0.84          0.80
# 8                 Arizona          AZ    2015         0.00          0.98
# 9                Arkansas          AR    2013         0.76          0.65
# 10               Arkansas          AR    2014         0.94          0.78
# 11               Arkansas          AR    2015         0.00          1.00
# ...

# %%
df['ONE MEASURE'].fillna((df['ONE MEASURE'].mean()),inplace=True)

# %%
df.head()
# Out:
#     REGION REGION_CODE  PERIOD  ONE MEASURE  IMMUNIZATION  LAB RESULTS  \
# 0  Alabama          AL    2013     0.900000          0.73         0.10
# 1  Alabama          AL    2014     0.900000          0.84         0.41
# 2  Alabama          AL    2015     0.841346          0.96         0.93
# 3   Alaska          AK    2013     1.000000          0.93         0.07
# 4   Alaska          AK    2014     0.890000          0.92         0.31
#
#    SYNDROMIC SURVEILLANCE  REGISTRY  STAGE 2 MEASURES  STAGE 1 MEASURES
# 0                    0.16       NaN              0.00              0.00
# 1                    0.50       NaN              0.96              0.17
# 2                    0.97      0.04               NaN               NaN
# 3                    0.00       NaN              0.00              0.00
# 4                    0.31       NaN              1.00              0.00

# %%
df['REGISTRY'].fillna((df['REGISTRY'].mean()),inplace=True)

# %%
df.head()
# Out:
#     REGION REGION_CODE  PERIOD  ONE MEASURE  IMMUNIZATION  LAB RESULTS  \
# 0  Alabama          AL    2013     0.900000          0.73         0.10
# 1  Alabama          AL    2014     0.900000          0.84         0.41
# 2  Alabama          AL    2015     0.841346          0.96         0.93
# 3   Alaska          AK    2013     1.000000          0.93         0.07
# 4   Alaska          AK    2014     0.890000          0.92         0.31
#
#    SYNDROMIC SURVEILLANCE  REGISTRY  STAGE 2 MEASURES  STAGE 1 MEASURES
# 0                    0.16  0.035769              0.00              0.00
# 1                    0.50  0.035769              0.96              0.17
# 2                    0.97  0.040000               NaN               NaN
# 3                    0.00  0.035769              0.00              0.00
# 4                    0.31  0.035769              1.00              0.00

# %%
df['STAGE 2 MEASURES'].fillna((df['STAGE 2 MEASURES'].mean()),inplace=True)

# %%
df.head()
# Out:
#     REGION REGION_CODE  PERIOD  ONE MEASURE  IMMUNIZATION  LAB RESULTS  \
# 0  Alabama          AL    2013     0.900000          0.73         0.10
# 1  Alabama          AL    2014     0.900000          0.84         0.41
# 2  Alabama          AL    2015     0.841346          0.96         0.93
# 3   Alaska          AK    2013     1.000000          0.93         0.07
# 4   Alaska          AK    2014     0.890000          0.92         0.31
#
#    SYNDROMIC SURVEILLANCE  REGISTRY  STAGE 2 MEASURES  STAGE 1 MEASURES
# 0                    0.16  0.035769          0.000000              0.00
# 1                    0.50  0.035769          0.960000              0.17
# 2                    0.97  0.040000          0.348558               NaN
# 3                    0.00  0.035769          0.000000              0.00
# 4                    0.31  0.035769          1.000000              0.00

# %%
df['STAGE 1 MEASURES'].fillna((df['STAGE 1 MEASURES'].mean()),inplace=True)

# %%
df.head()
# Out:
#     REGION REGION_CODE  PERIOD  ONE MEASURE  IMMUNIZATION  LAB RESULTS  \
# 0  Alabama          AL    2013     0.900000          0.73         0.10
# 1  Alabama          AL    2014     0.900000          0.84         0.41
# 2  Alabama          AL    2015     0.841346          0.96         0.93
# 3   Alaska          AK    2013     1.000000          0.93         0.07
# 4   Alaska          AK    2014     0.890000          0.92         0.31
#
#    SYNDROMIC SURVEILLANCE  REGISTRY  STAGE 2 MEASURES  STAGE 1 MEASURES
# 0                    0.16  0.035769          0.000000             0.000
# 1                    0.50  0.035769          0.960000             0.170
# 2                    0.97  0.040000          0.348558             0.025
# 3                    0.00  0.035769          0.000000             0.000
# 4                    0.31  0.035769          1.000000             0.000

# %%
df.shape
# Out:
# (156, 10)

# %%
df
# Out:
#                    region region_code  period  atleast_one_measure  \
# 0                 Alabama          AL    2013                 0.90
# 1                 Alabama          AL    2014                 0.90
# 2                 Alabama          AL    2015                  NaN
# 3                  Alaska          AK    2013                 1.00
# 4                  Alaska          AK    2014                 0.89
# 5                  Alaska          AK    2015                  NaN
# 6                 Arizona          AZ    2013                 0.93
# 7                 Arizona          AZ    2014                 0.84
# 8                 Arizona          AZ    2015                  NaN
# 9                Arkansas          AR    2013                 0.76
# 10               Arkansas          AR    2014                 0.94
# 11               Arkansas          AR    2015                  NaN
# 12             California          CA    2013                 0.82
# ...
